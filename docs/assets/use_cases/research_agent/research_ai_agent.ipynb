# %% [markdown]
# <a href="https://colab.research.google.com/github/7dash/7dash/blob/main/docs/assets/use_cases/research_agent/research_ai_agent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Installing required packages

# %%
# %%capture
# %pip install -q --upgrade --force-reinstall --no-cache-dir "numpy>=2.0" superlinked==23.7.0 openai

# %%
# !pip install superlinked
# Out:
# Requirement already satisfied: superlinked in /usr/local/lib/python3.12/dist-packages (35.1.1)
# Requirement already satisfied: Deprecated<2.0.0,>=1.2.18 in /usr/local/lib/python3.12/dist-packages (from superlinked) (1.2.18)
# Requirement already satisfied: aiofiles<25.0.0,>=24.1.0 in /usr/local/lib/python3.12/dist-packages (from superlinked) (24.1.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.11.18 in /usr/local/lib/python3.12/dist-packages (from superlinked) (3.12.15)
# Requirement already satisfied: asgi-correlation-id<5.0.0,>=4.3.4 in /usr/local/lib/python3.12/dist-packages (from superlinked) (4.3.4)
# Requirement already satisfied: beartype<0.22.0,>=0.17.2 in /usr/local/lib/python3.12/dist-packages (from superlinked) (0.21.0)
# Requirement already satisfied: cachetools<6.0,>=5.4 in /usr/local/lib/python3.12/dist-packages (from superlinked) (5.5.2)
# Requirement already satisfied: certifi<2026.0.0,>=2024.7.4 in /usr/local/lib/python3.12/dist-packages (from superlinked) (2025.8.3)
# Requirement already satisfied: filelock<4.0.0,>=3.16.1 in /usr/local/lib/python3.12/dist-packages (from superlinked) (3.19.1)
# Requirement already satisfied: furl<3.0.0,>=2.1.3 in /usr/local/lib/python3.12/dist-packages (from superlinked) (2.1.4)
# Requirement already satisfied: graphviz<0.22.0,>=0.20.1 in /usr/local/lib/python3.12/dist-packages (from superlinked) (0.21)
# Requirement already satisfied: instructor<2.0.0,>=1.3.7 in /usr/local/lib/python3.12/dist-packages (from superlinked) (1.10.0)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from superlinked) (3.1.6)
# Requirement already satisfied: modal==1.1.1 in /usr/local/lib/python3.12/dist-packages (from superlinked) (1.1.1)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from superlinked) (1.6.0)
# Requirement already satisfied: nltk<4.0.0,>=3.9.1 in /usr/local/lib/python3.12/dist-packages (from superlinked) (3.9.1)
# Requirement already satisfied: numpy<=3.0.0,>=1.25.2 in /usr/local/lib/python3.12/dist-packages (from superlinked) (2.0.2)
# Requirement already satisfied: open_clip_torch<4.0.0,>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from superlinked) (3.1.0)
# Requirement already satisfied: opentelemetry-api<2.0.0,>=1.34.1 in /usr/local/lib/python3.12/dist-packages (from superlinked) (1.36.0)
# Requirement already satisfied: opentelemetry-sdk<2.0.0,>=1.34.1 in /usr/local/lib/python3.12/dist-packages (from superlinked) (1.36.0)
# Requirement already satisfied: pandas<3.0.0,>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from superlinked) (2.2.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.6.4 in /usr/local/lib/python3.12/dist-packages (from superlinked) (2.11.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from superlinked) (2.10.1)
# Requirement already satisfied: requests<3.0,>=2.31 in /usr/local/lib/python3.12/dist-packages (from superlinked) (2.32.4)
# Requirement already satisfied: rich!=14.0.0 in /usr/local/lib/python3.12/dist-packages (from superlinked) (13.9.4)
# Requirement already satisfied: sentence-transformers<6.0.0,>=5.0.0 in /usr/local/lib/python3.12/dist-packages (from superlinked) (5.1.0)
# Requirement already satisfied: setuptools<81.0.0,>=70.1.1 in /usr/local/lib/python3.12/dist-packages (from superlinked) (75.2.0)
# Requirement already satisfied: structlog!=25.4.0,<26.0,>=24.4 in /usr/local/lib/python3.12/dist-packages (from superlinked) (25.3.0)
# Requirement already satisfied: torch<3.0.0,>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from superlinked) (2.8.0+cu126)
# Requirement already satisfied: typing_extensions>=3.10.0.2 in /usr/local/lib/python3.12/dist-packages (from superlinked) (4.14.1)
# Requirement already satisfied: click~=8.1 in /usr/local/lib/python3.12/dist-packages (from modal==1.1.1->superlinked) (8.2.1)
# Requirement already satisfied: grpclib<0.4.9,>=0.4.7 in /usr/local/lib/python3.12/dist-packages (from modal==1.1.1->superlinked) (0.4.8)
# Requirement already satisfied: protobuf!=4.24.0,<7.0,>=3.19 in /usr/local/lib/python3.12/dist-packages (from modal==1.1.1->superlinked) (5.29.5)
# Requirement already satisfied: synchronicity~=0.10.1 in /usr/local/lib/python3.12/dist-packages (from modal==1.1.1->superlinked) (0.10.2)
# Requirement already satisfied: toml in /usr/local/lib/python3.12/dist-packages (from modal==1.1.1->superlinked) (0.10.2)
# Requirement already satisfied: typer>=0.9 in /usr/local/lib/python3.12/dist-packages (from modal==1.1.1->superlinked) (0.16.0)
# Requirement already satisfied: types-certifi in /usr/local/lib/python3.12/dist-packages (from modal==1.1.1->superlinked) (2021.10.8.3)
# Requirement already satisfied: types-toml in /usr/local/lib/python3.12/dist-packages (from modal==1.1.1->superlinked) (0.10.8.20240310)
# Requirement already satisfied: watchfiles in /usr/local/lib/python3.12/dist-packages (from modal==1.1.1->superlinked) (1.1.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.11.18->superlinked) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.11.18->superlinked) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.11.18->superlinked) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.11.18->superlinked) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.11.18->superlinked) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.11.18->superlinked) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.11.18->superlinked) (1.20.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from asgi-correlation-id<5.0.0,>=4.3.4->superlinked) (25.0)
# Requirement already satisfied: starlette>=0.18 in /usr/local/lib/python3.12/dist-packages (from asgi-correlation-id<5.0.0,>=4.3.4->superlinked) (0.47.2)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.12/dist-packages (from Deprecated<2.0.0,>=1.2.18->superlinked) (1.17.3)
# Requirement already satisfied: six>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from furl<3.0.0,>=2.1.3->superlinked) (1.17.0)
# Requirement already satisfied: orderedmultidict>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from furl<3.0.0,>=2.1.3->superlinked) (1.0.1)
# Requirement already satisfied: diskcache>=5.6.3 in /usr/local/lib/python3.12/dist-packages (from instructor<2.0.0,>=1.3.7->superlinked) (5.6.3)
# Requirement already satisfied: docstring-parser<1.0,>=0.16 in /usr/local/lib/python3.12/dist-packages (from instructor<2.0.0,>=1.3.7->superlinked) (0.17.0)
# Requirement already satisfied: jiter<0.11,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from instructor<2.0.0,>=1.3.7->superlinked) (0.10.0)
# Requirement already satisfied: openai<2.0.0,>=1.70.0 in /usr/local/lib/python3.12/dist-packages (from instructor<2.0.0,>=1.3.7->superlinked) (1.100.0)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.0 in /usr/local/lib/python3.12/dist-packages (from instructor<2.0.0,>=1.3.7->superlinked) (2.33.2)
# Requirement already satisfied: tenacity<10.0.0,>=8.2.3 in /usr/local/lib/python3.12/dist-packages (from instructor<2.0.0,>=1.3.7->superlinked) (8.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2<4.0.0,>=3.1.4->superlinked) (3.0.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk<4.0.0,>=3.9.1->superlinked) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk<4.0.0,>=3.9.1->superlinked) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from nltk<4.0.0,>=3.9.1->superlinked) (4.67.1)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from open_clip_torch<4.0.0,>=3.0.0->superlinked) (0.23.0+cu126)
# Requirement already satisfied: ftfy in /usr/local/lib/python3.12/dist-packages (from open_clip_torch<4.0.0,>=3.0.0->superlinked) (6.3.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.12/dist-packages (from open_clip_torch<4.0.0,>=3.0.0->superlinked) (0.34.4)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.12/dist-packages (from open_clip_torch<4.0.0,>=3.0.0->superlinked) (0.6.2)
# Requirement already satisfied: timm>=1.0.17 in /usr/local/lib/python3.12/dist-packages (from open_clip_torch<4.0.0,>=3.0.0->superlinked) (1.0.19)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-api<2.0.0,>=1.34.1->superlinked) (8.7.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.57b0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-sdk<2.0.0,>=1.34.1->superlinked) (0.57b0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0.0,>=2.0.3->superlinked) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0.0,>=2.0.3->superlinked) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0.0,>=2.0.3->superlinked) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.6.4->superlinked) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.6.4->superlinked) (0.4.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings<3.0.0,>=2.4.0->superlinked) (1.1.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0,>=2.31->superlinked) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0,>=2.31->superlinked) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0,>=2.31->superlinked) (2.5.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich!=14.0.0->superlinked) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich!=14.0.0->superlinked) (2.19.2)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers<6.0.0,>=5.0.0->superlinked) (4.55.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from sentence-transformers<6.0.0,>=5.0.0->superlinked) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from sentence-transformers<6.0.0,>=5.0.0->superlinked) (1.16.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from sentence-transformers<6.0.0,>=5.0.0->superlinked) (11.3.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.8.0->superlinked) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.8.0->superlinked) (3.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.8.0->superlinked) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.8.0->superlinked) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.8.0->superlinked) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.8.0->superlinked) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.8.0->superlinked) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.8.0->superlinked) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.8.0->superlinked) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.8.0->superlinked) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.8.0->superlinked) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.8.0->superlinked) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.8.0->superlinked) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.8.0->superlinked) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.8.0->superlinked) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.8.0->superlinked) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.8.0->superlinked) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.8.0->superlinked) (3.4.0)
# Requirement already satisfied: h2<5,>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from grpclib<0.4.9,>=0.4.7->modal==1.1.1->superlinked) (4.2.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->open_clip_torch<4.0.0,>=3.0.0->superlinked) (6.0.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->open_clip_torch<4.0.0,>=3.0.0->superlinked) (1.1.7)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api<2.0.0,>=1.34.1->superlinked) (3.23.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich!=14.0.0->superlinked) (0.1.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai<2.0.0,>=1.70.0->instructor<2.0.0,>=1.3.7->superlinked) (4.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai<2.0.0,>=1.70.0->instructor<2.0.0,>=1.3.7->superlinked) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from openai<2.0.0,>=1.70.0->instructor<2.0.0,>=1.3.7->superlinked) (0.28.1)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai<2.0.0,>=1.70.0->instructor<2.0.0,>=1.3.7->superlinked) (1.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3.0.0,>=2.8.0->superlinked) (1.3.0)
# Requirement already satisfied: sigtools>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from synchronicity~=0.10.1->modal==1.1.1->superlinked) (4.0.1)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers<6.0.0,>=5.0.0->superlinked) (0.21.4)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.9->modal==1.1.1->superlinked) (1.5.4)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from ftfy->open_clip_torch<4.0.0,>=3.0.0->superlinked) (0.2.13)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->sentence-transformers<6.0.0,>=5.0.0->superlinked) (3.6.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in /usr/local/lib/python3.12/dist-packages (from h2<5,>=3.1.0->grpclib<0.4.9,>=0.4.7->modal==1.1.1->superlinked) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /usr/local/lib/python3.12/dist-packages (from h2<5,>=3.1.0->grpclib<0.4.9,>=0.4.7->modal==1.1.1->superlinked) (4.1.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.70.0->instructor<2.0.0,>=1.3.7->superlinked) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.70.0->instructor<2.0.0,>=1.3.7->superlinked) (0.16.0)

# %% [markdown]
# ### Setting up the Imports and setting up the intial library checks

# %%
import pandas as pd
import superlinked.framework as sl
from datetime import timedelta
from sentence_transformers import SentenceTransformer
# from openai import OpenAI # Remove OpenAI import
import google.generativeai as genai # Import Gemini API
import os
from abc import ABC, abstractmethod
from typing import Any, Optional, Dict
from tqdm import tqdm
from google.colab import userdata

# Abstract Tool Class
class Tool(ABC):
    @abstractmethod
    def name(self) -> str:
        pass

    @abstractmethod
    def description(self) -> str:
        pass

    @abstractmethod
    def use(self, *args, **kwargs) -> Any:
        pass


# Get API key from Google Colab secrets
try:
    # api_key = userdata.get('OPENAI_API_KEY') # Remove OpenAI API key retrieval
    GOOGLE_API_KEY=userdata.get('GOOGLE_API_KEY') # Get Gemini API key
except KeyError:
    # raise ValueError("OPENAI_API_KEY not found in user secrets. Please add it using Tools > User secrets.") # Update error message
    raise ValueError("GOOGLE_API_KEY not found in user secrets. Please add it using Tools > User secrets.")

# Initialize Gemini Client
# api_key = os.environ.get("OPENAI_API_KEY", "your-openai-key")  # Remove OpenAI API key initialization
# if not api_key: # Remove OpenAI API key check
#     raise ValueError("Please set the OPENAI_API_KEY environment variable.") # Remove OpenAI API key error

# client = OpenAI(api_key=api_key) # Remove OpenAI client initialization
genai.configure(api_key=GOOGLE_API_KEY) # Configure Gemini API
client = genai # Use genai as client
model = "gemini-1.5-flash-latest" # Use Gemini model

# %% [markdown]
# ### Downloading the relevant data

# %%
import pandas as pd

# !wget --no-check-certificate 'https://drive.google.com/uc?export=download&id=1FCR3TW5yLjGhEmm-Uclw0_5PWVEaLk1j' -O arxiv_ai_data.csv
# Out:
# --2025-08-26 13:38:04--  https://drive.google.com/uc?export=download&id=1FCR3TW5yLjGhEmm-Uclw0_5PWVEaLk1j
# Resolving drive.google.com (drive.google.com)... 108.177.12.138, 108.177.12.139, 108.177.12.113, ...
# Connecting to drive.google.com (drive.google.com)|108.177.12.138|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1FCR3TW5yLjGhEmm-Uclw0_5PWVEaLk1j&export=download [following]
# --2025-08-26 13:38:04--  https://drive.usercontent.google.com/download?id=1FCR3TW5yLjGhEmm-Uclw0_5PWVEaLk1j&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 173.194.216.132, 2607:f8b0:400c:c08::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|173.194.216.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13941471 (13M) [application/octet-stream]
# Saving to: ‘arxiv_ai_data.csv’
#
# arxiv_ai_data.csv   100%[===================>]  13.29M  37.2MB/s    in 0.4s
#
# 2025-08-26 13:38:08 (37.2 MB/s) - ‘arxiv_ai_data.csv’ saved [13941471/13941471]

# %% [markdown]
# ### Data Loading and Truncation
#
# To improve loading times, especially for users on the free Colab tier, the dataset is truncated to 100 rows by default. This means that only the first 100 entries from the original CSV file are loaded initially. You can change it to use the full dataset if you want!

# %%
df = pd.read_csv('arxiv_ai_data.csv').head(100)
df.head()
# Out:
#                                              authors categories  \
# 0            [arxiv.Result.Author('M. L. Ginsberg')]  ['cs.AI']
# 1             [arxiv.Result.Author('M. P. Wellman')]  ['cs.AI']
# 2  [arxiv.Result.Author('I. P. Gent'), arxiv.Resu...  ['cs.AI']
# 3  [arxiv.Result.Author('F. Bergadano'), arxiv.Re...  ['cs.AI']
# 4  [arxiv.Result.Author('J. C. Schlimmer'), arxiv...  ['cs.AI']
#
#                                              comment  doi  \
# 0  See http://www.jair.org/ for an online appendi...  NaN
# 1  See http://www.jair.org/ for any accompanying ...  NaN
# 2  See http://www.jair.org/ for any accompanying ...  NaN
# 3  See http://www.jair.org/ for any accompanying ...  NaN
# 4  See http://www.jair.org/ for an online appendi...  NaN
#
#                             entry_id  \
# 0  http://arxiv.org/abs/cs/9308101v1
# 1  http://arxiv.org/abs/cs/9308102v1
# 2  http://arxiv.org/abs/cs/9309101v1
# 3  http://arxiv.org/abs/cs/9311101v1
# 4  http://arxiv.org/abs/cs/9311102v1
#
#                                          journal_ref  \
# 0  Journal of Artificial Intelligence Research, V...
# 1  Journal of Artificial Intelligence Research, V...
# 2  Journal of Artificial Intelligence Research, V...
# 3  Journal of Artificial Intelligence Research, V...
# 4  Journal of Artificial Intelligence Research, V...
#
#                              pdf_url primary_category  \
# 0  http://arxiv.org/pdf/cs/9308101v1            cs.AI
# 1  http://arxiv.org/pdf/cs/9308102v1            cs.AI
# 2  http://arxiv.org/pdf/cs/9309101v1            cs.AI
# 3  http://arxiv.org/pdf/cs/9311101v1            cs.AI
# 4  http://arxiv.org/pdf/cs/9311102v1            cs.AI
#
#                    published  \
# 0  1993-08-01 00:00:00+00:00
# 1  1993-08-01 00:00:00+00:00
# 2  1993-09-01 00:00:00+00:00
# 3  1993-11-01 00:00:00+00:00
# 4  1993-11-01 00:00:00+00:00
#
#                                              summary  \
# 0  Because of their occasional need to return to ...
# 1  Market price systems constitute a well-underst...
# 2  We describe an extensive study of search in GS...
# 3  As real logic programmers normally use cut (!)...
# 4  To support the goal of allowing users to recor...
#
#                                                title  \
# 0                               Dynamic Backtracking
# 1  A Market-Oriented Programming Environment and ...
# 2            An Empirical Analysis of Search in GSAT
# 3  The Difficulties of Learning Logic Programs wi...
# 4  Software Agents: Completing Patterns and Const...
#
#                      updated
# 0  1993-08-01 00:00:00+00:00
# 1  1993-08-01 00:00:00+00:00
# 2  1993-09-01 00:00:00+00:00
# 3  1993-11-01 00:00:00+00:00
# 4  1993-11-01 00:00:00+00:00

# %%
df.columns
# Out:
# Index(['authors', 'categories', 'comment', 'doi', 'entry_id', 'journal_ref',
#        'pdf_url', 'primary_category', 'published', 'summary', 'title',
#        'updated'],
#       dtype='object')

# %%
df = pd.read_csv('arxiv_ai_data.csv').head(100)

# Convert to datetime but keep it as datetime (more readable and usable)
df['published'] = pd.to_datetime(df['published'])

# Ensure summary is a string
df['summary'] = df['summary'].astype(str)

# Add 'text' column for similarity search
df['text'] = df['title'] + " " + df['summary']

# %%
# Sort the DataFrame by published date in descending order (newest first)
df_sorted = df.sort_values(by='published', ascending=False)

# Display the 5 most recent papers
print("5 Most Recent Papers:")
print("-" * 50)
for idx, row in df_sorted.head().iterrows():
    print(f"Date: {row['published'].strftime('%Y-%m-%d')}")
    print(f"Title: {row['title']}")
    print("-" * 50)

# Optional: Display the oldest papers too
print("\n5 Oldest Papers:")
print("-" * 50)
for idx, row in df_sorted.tail().iterrows():
    print(f"Date: {row['published'].strftime('%Y-%m-%d')}")
    print(f"Title: {row['title']}")
    print("-" * 50)
# Out:
# 5 Most Recent Papers:
# --------------------------------------------------
# Date: 1998-06-01
# Title: A Selective Macro-learning Algorithm and its Application to the NxN Sliding-Tile Puzzle
# --------------------------------------------------
# Date: 1998-06-01
# Title: Model-Based Diagnosis using Structured System Descriptions
# --------------------------------------------------
# Date: 1998-05-01
# Title: Integrative Windowing
# --------------------------------------------------
# Date: 1998-03-01
# Title: Tractability of Theory Patching
# --------------------------------------------------
# Date: 1998-03-01
# Title: Cached Sufficient Statistics for Efficient Machine Learning with Large Datasets
# --------------------------------------------------
#
# 5 Oldest Papers:
# --------------------------------------------------
# Date: 1993-11-01
# Title: Software Agents: Completing Patterns and Constructing User Interfaces
# --------------------------------------------------
# Date: 1993-11-01
# Title: The Difficulties of Learning Logic Programs with Cut
# --------------------------------------------------
# Date: 1993-09-01
# Title: An Empirical Analysis of Search in GSAT
# --------------------------------------------------
# Date: 1993-08-01
# Title: A Market-Oriented Programming Environment and its Application to Distributed Multicommodity Flow Problems
# --------------------------------------------------
# Date: 1993-08-01
# Title: Dynamic Backtracking
# --------------------------------------------------

# %% [markdown]
# ## Understanding Time-Aware Paper Discovery with RecencySpace
#
# When searching through research papers, finding relevant content is only half the story - knowing when it was published can be just as important. That's why we've implemented a smart time-aware search system using RecencySpace. Imagine you're organizing your digital library: you want to find papers not just by what they're about, but also by when they were written. Our system does exactly that, but automatically and intelligently.
#
# We've set up our search to look at both what a paper contains and when it was published. Using different time windows (like papers from the last few months, the last year, or even older), our system can prioritize papers based on their publication dates while still keeping track of their relevance to your search. It's like having a research assistant who knows exactly how to balance the importance of time and content in your search results.
#
# For our collection of AI research papers this time-aware approach helps us understand how ideas evolved during these foundational years. When you search for topics like "quantum computing" or "neural networks," the system doesn't just find papers containing these terms - it also considers their place in the timeline of AI development. This makes it easier to trace how concepts developed and changed over time, giving us a clearer picture of AI's historical progression.

# %%
class PaperSchema(sl.Schema):
    text: sl.String
    published: sl.Timestamp  # This will handle datetime objects properly
    entry_id: sl.IdField
    title: sl.String
    summary: sl.String

paper = PaperSchema()

# Define spaces
text_space = sl.TextSimilaritySpace(
    text=sl.chunk(paper.text, chunk_size=200, chunk_overlap=50),
    model="sentence-transformers/all-mpnet-base-v2"
)
recency_space = sl.RecencySpace(
    timestamp=paper.published,
    period_time_list=[
        sl.PeriodTime(timedelta(days=365)),      # papers within 1 year
        sl.PeriodTime(timedelta(days=2*365)),    # papers within 2 years
        sl.PeriodTime(timedelta(days=3*365)),    # papers within 3 years
    ],
    negative_filter=-0.25
)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Fetching 28 files:   0%|          | 0/28 [00:00<?, ?it/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# .gitattributes: 0.00B [00:00, ?B/s]
# data_config.json: 0.00B [00:00, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# onnx/model_O1.onnx:   0%|          | 0.00/436M [00:00<?, ?B/s]
# onnx/model.onnx:   0%|          | 0.00/436M [00:00<?, ?B/s]
# onnx/model_O3.onnx:   0%|          | 0.00/436M [00:00<?, ?B/s]
# onnx/model_O2.onnx:   0%|          | 0.00/436M [00:00<?, ?B/s]
# onnx/model_qint8_arm64.onnx:   0%|          | 0.00/110M [00:00<?, ?B/s]
# onnx/model_O4.onnx:   0%|          | 0.00/218M [00:00<?, ?B/s]
# onnx/model_quint8_avx2.onnx:   0%|          | 0.00/110M [00:00<?, ?B/s]
# openvino/openvino_model.bin:   0%|          | 0.00/436M [00:00<?, ?B/s]
# openvino_model.xml: 0.00B [00:00, ?B/s]
# openvino/openvino_model_qint8_quantized.(…):   0%|          | 0.00/110M [00:00<?, ?B/s]
# openvino_model_qint8_quantized.xml: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# train_script.py: 0.00B [00:00, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]

# %% [markdown]
# ### Creating the index and ingesting the relevant data. we are using the in-memory superlinked executor to ingest the data

# %%
# Create the index
paper_index = sl.Index([text_space, recency_space])

# Parser to map DataFrame columns to schema fields
parser = sl.DataFrameParser(
    paper,
    mapping={
        paper.entry_id: "entry_id",
        paper.published: "published",
        paper.text: "text",
        paper.title: "title",
        paper.summary: "summary",
    }
)

# Set up in-memory source and executor
source = sl.InMemorySource(paper, parser=parser)
executor = sl.InMemoryExecutor(sources=[source], indices=[paper_index])
app = executor.run()

# Load the DataFrame with a progress bar using batches
batch_size = 10
data_batches = [df[i:i + batch_size] for i in range(0, len(df), batch_size)]
for batch in tqdm(data_batches, total=len(data_batches), desc="Loading Data into Source"):
    source.put([batch])
# Out:
# Loading Data into Source:  30%|███       | 3/10 [07:54<18:50, 161.47s/it]

# %% [markdown]
# ### Query definition

# %%
# Define the query
knowledgebase_query = (
    sl.Query(
        paper_index,
        weights={
            text_space: sl.Param("relevance_weight"),
            recency_space: sl.Param("recency_weight"),
        }
    )
    .find(paper)
    .similar(text_space, sl.Param("search_query"))
    .select(paper.entry_id, paper.published, paper.text, paper.title, paper.summary)
    .limit(sl.Param("limit"))
)

# %% [markdown]
# ### Defining the tools for the kernel agent

# %% [markdown]
# ### Retrieval Tool

# %%
class RetrievalTool(Tool):
    def __init__(self, df, app, knowledgebase_query, client, model):
        self.df = df
        self.app = app
        self.knowledgebase_query = knowledgebase_query
        self.client = client
        self.model = model

    def name(self) -> str:
        return "RetrievalTool"

    def description(self) -> str:
        return "Retrieves a list of relevant papers based on a query using Superlinked."

    def use(self, query: str) -> pd.DataFrame:
        result = self.app.query(
            self.knowledgebase_query,
            relevance_weight=1.0,
            recency_weight=0.5,
            search_query=query,
            limit=5
        )
        df_result = sl.PandasConverter.to_pandas(result)
        # Ensure summary is a string
        if 'summary' in df_result.columns:
            df_result['summary'] = df_result['summary'].astype(str)
        else:
            print("Warning: 'summary' column not found in retrieved DataFrame.")
        return df_result

# %% [markdown]
# ### Summarization Tool

# %%
class SummarizationTool(Tool):
    def __init__(self, df, client, model):
        self.df = df
        self.client = client
        self.model = model

    def name(self) -> str:
        return "SummarizationTool"

    def description(self) -> str:
        return "Generates a concise summary of specified papers using an LLM."

    def use(self, query: str, paper_ids: list) -> str:
        papers = self.df[self.df['entry_id'].isin(paper_ids)]
        if papers.empty:
            return "No papers found with the given IDs."
        summaries = papers['summary'].tolist()
        summary_str = "\n\n".join(summaries)
        prompt = f"""
        Summarize the following paper summaries:\n\n{summary_str}\n\nProvide a concise summary.
        """
        # response = self.client.chat.completions.create( # Remove OpenAI API call
        #     model=self.model,
        #     messages=[{"role": "user", "content": prompt}],
        #     temperature=0.7,
        #     max_tokens=500
        # )
        response = self.client.generate_content(prompt) # Use Gemini API call
        return response.text.strip() # Get text from Gemini response

# %% [markdown]
# ### Question Answer Tool

# %%
class QuestionAnsweringTool(Tool):
    def __init__(self, retrieval_tool, client, model):
        self.retrieval_tool = retrieval_tool
        self.client = client
        self.model = model

    def name(self) -> str:
        return "QuestionAnsweringTool"

    def description(self) -> str:
        return "Answers questions about research topics using retrieved paper summaries or general knowledge if no specific context is available."

    def use(self, query: str) -> str:
        df_result = self.retrieval_tool.use(query)
        if 'summary' not in df_result.columns:
            # Tag as a general question if summary is missing
            prompt = f"""
            You are a knowledgeable research assistant. This is a general question tagged as [GENERAL]. Answer based on your broad knowledge, not limited to specific paper summaries. If you don't know the answer, provide a brief explanation of why.

            User's question: {query}
            """
        else:
            # Use paper summaries for specific context
            contexts = df_result['summary'].tolist()
            context_str = "\n\n".join(contexts)
            prompt = f"""
            You are a research assistant. Use the following paper summaries to answer the user's question. If you don't know the answer based on the summaries, say 'I don't know.'

            Paper summaries:
            {context_str}

            User's question: {query}
            """
        # response = self.client.chat.completions.create( # Remove OpenAI API call
        #     model=self.model,
        #     messages=[{"role": "user", "content": prompt}],
        #     temperature=0.7,
        #     max_tokens=500
        # )
        response = self.client.generate_content(prompt) # Use Gemini API call
        return response.text.strip() # Get text from Gemini response

# %% [markdown]
# ### Setting up the kernel agent

# %%
class KernelAgent:
    def __init__(self, retrieval_tool: RetrievalTool, summarization_tool: SummarizationTool, question_answering_tool: QuestionAnsweringTool, client, model):
        self.retrieval_tool = retrieval_tool
        self.summarization_tool = summarization_tool
        self.question_answering_tool = question_answering_tool
        self.client = client
        self.model = model

    def classify_query(self, query: str) -> str:
        prompt = f"""
        Classify the following user prompt into one of the three categories:
        - retrieval: The user wants to find a list of papers based on some criteria (e.g., 'Find papers on AI ethics from 2020').
        - summarization: The user wants to summarize a list of papers (e.g., 'Summarize papers with entry_id 123, 456, 789').
        - question_answering: The user wants to ask a question about research topics and get an answer (e.g., 'What is the latest development in AI ethics?').

        User prompt: {query}

        Respond with only the category name (retrieval, summarization, question_answering).
        If unsure, respond with 'unknown'.
        """
        # response = self.client.chat.completions.create( # Remove OpenAI API call
        #     model=self.model,
        #     messages=[{"role": "user", "content": prompt}],
        #     temperature=0.7,
        #     max_tokens=10
        # )
        response = self.client.generate_content(prompt) # Use Gemini API call
        classification = response.text.strip().lower() # Get text from Gemini response
        print(f"Query type: {classification}")
        return classification

    def process_query(self, query: str, params: Optional[Dict] = None) -> str:
        query_type = self.classify_query(query)
        if query_type == 'retrieval':
            df_result = self.retrieval_tool.use(query)
            response = "Here are the top papers:\n"
            for i, row in df_result.iterrows():
                # Ensure summary is a string and handle empty cases
                summary = str(row['summary']) if pd.notna(row['summary']) else ""
                response += f"{i+1}. {row['title']} \nSummary: {summary[:200]}...\n\n"
            return response
        elif query_type == 'summarization':
            if not params or 'paper_ids' not in params:
                return "Error: Summarization query requires a 'paper_ids' parameter with a list of entry_ids."
            return self.summarization_tool.use(query, params['paper_ids'])
        elif query_type == 'question_answering':
            return self.question_answering_tool.use(query)
        else:
            return "Error: Unable to classify query as 'retrieval', 'summarization', or 'question_answering'."

# %%
retrieval_tool = RetrievalTool(df, app, knowledgebase_query, client, model)
summarization_tool = SummarizationTool(df, client, model)
question_answering_tool = QuestionAnsweringTool(retrieval_tool, client, model)

# Initialize KernelAgent
kernel_agent = KernelAgent(retrieval_tool, summarization_tool, question_answering_tool, client, model)

# %%
# Test query
print(kernel_agent.process_query("Find papers on quantum computing in last 10 years"))
# Out:
# Query type: retrieval
# Here are the top papers:
# 1. Quantum Computing and Phase Transitions in Combinatorial Search
# Summary: We introduce an algorithm for combinatorial search on quantum computers that
# is capable of significantly concentrating amplitude into solutions for some NP
# search problems, on average. This is done by...
#
# 2. The Road to Quantum Artificial Intelligence
# Summary: This paper overviews the basic principles and recent advances in the emerging
# field of Quantum Computation (QC), highlighting its potential application to
# Artificial Intelligence (AI). The paper provi...
#
# 3. Solving Highly Constrained Search Problems with Quantum Computers
# Summary: A previously developed quantum search algorithm for solving 1-SAT problems in
# a single step is generalized to apply to a range of highly constrained k-SAT
# problems. We identify a bound on the number o...
#
# 4. The model of quantum evolution
# Summary: This paper has been withdrawn by the author due to extremely unscientific
# errors....
#
# 5. Artificial and Biological Intelligence
# Summary: This article considers evidence from physical and biological sciences to show
# machines are deficient compared to biological systems at incorporating
# intelligence. Machines fall short on two counts: fi...

# %%
print(kernel_agent.process_query("Summarize this paper", params={"paper_ids": ["http://arxiv.org/abs/cs/9311101v1"]}))
# Out:
# Query type: summarization
# The paper discusses the challenges of learning logic programs that contain the cut predicate. It suggests a method of first generating a base program without cut and then adding cut where necessary to make it consistent with the positive examples. The paper concludes that learning programs with cut is difficult due to the need for intensional evaluation, and current induction techniques may need to be restricted to purely declarative logic languages.
